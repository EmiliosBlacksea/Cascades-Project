# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
# %cd /content/drive/Othercomputers/My Laptop/Cascades
# !ls

# %%
# !python src/laptop_stress_test.py \
  --processed_dir "processed" \
  --k_min 1 --k_max 1 \
  --models mlp \
  --device cpu \
  --out_dir "reports" \
  --log "reports/overnight_loo.log" \
  --max_drop_features 3
